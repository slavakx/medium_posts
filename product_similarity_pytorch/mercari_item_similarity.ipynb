# %% [markdown]
# # Load the model and get embeddings

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import pandas as pd

pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000)
pd.set_option('display.width', 1000)
pd.set_option('display.max_colwidth', None)

# %%
import spacy

# %%
#keras tokenizer
from keras.preprocessing import text
from keras.preprocessing import sequence # for import pad_sequences

# %%
#pytorch tokenizer
import torch
import torch.nn as nn
import torchtext
from torchtext.data import get_tokenizer
from torchtext.vocab import vocab


from torch.utils.data import DataLoader
from torch.nn.utils.rnn import pad_sequence

import pytorch_lightning as pl
from pytorch_lightning.callbacks.early_stopping import EarlyStopping
from pytorch_lightning.callbacks.model_checkpoint import ModelCheckpoint
from pytorch_lightning.callbacks import ModelSummary, LearningRateMonitor

from pytorch_lightning.loggers import WandbLogger


from torch_lr_finder import LRFinder

# %%
from collections import Counter, OrderedDict, defaultdict

import json

import plotly.express as px
import plotly.io as pio
pio.renderers.default = 'iframe' # or 'notebook' or 'colab' or 'jupyterlab'
from sklearn.manifold import TSNE
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import normalize

# %%
from IPython.core.debugger import set_trace

# %%
import socket
import re

# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"
#os.environ["WANDB_NOTEBOOK_NAME"] = os.path.join(os.getcwd(), "notebook")

#https://docs.nvidia.com/cuda/cublas/index.html#cublasApi_reproducibility
os.environ["UBLAS_WORKSPACE_CONFIG"] = ":4096:8"

# %%
import joblib

# %%
import wandb

# %%
import gc
import random
import numpy as np
np.set_printoptions(suppress=True)
#np.set_printoptions(threshold=np.inf)
torch.set_printoptions(sci_mode = False)

is_cuda = torch.cuda.is_available()


if is_cuda:
    print(is_cuda)
    print(torch.cuda.current_device())
    print(torch.cuda.device_count())
    print(torch.cuda.get_device_name(0))
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    
else:
    device = torch.device("cpu")

    
print('Using device:', device)   
SEED = 1234

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.backends.cudnn.deterministic = True
#torch.use_deterministic_algorithms(True)

#print(print(torch.cuda.memory_summary(device=None, abbreviated=False)))
# Out:
# True
# 0
# 1
# Quadro RTX 4000
# Using device: cuda

# %%
import sys
sys.path.append("./prediction/")

import pytorch_dataset as pytorch_dataset
import pytorch_model as pytorch_model
import utils as utils

# %%
model_dump_path = "./model"

# %% [markdown]
# ## Load Model and Data Dump

# %%
file_template = "epoch07-loss0.24-val_loss0.34-rmsle0.429"
data_dump_file = f"data_dump_{file_template}.dump"
model_file = f"{file_template}.ckpt"

# %%
data_dump = joblib.load(os.path.join(model_dump_path, data_dump_file))

# %%
data_dump.keys()
# Out:
# dict_keys(['train_set', 'dd_train', 'validation_set', 'model'])

# %%
dd_train = data_dump["dd_train"]

# %%
train = data_dump["train_set"].reset_index(drop=True)
validation = data_dump["validation_set"].reset_index(drop=True)

# %%
train.shape
# Out:
# (1185328, 16)

# %%
validation.shape
# Out:
# (296333, 16)

# %%
set(validation["name"]) - set(train["name"])
# Out:
# {'southpole black down jacket sz s',
#  'vs pink pastel watercolor bikini top',
#  "jordan retro 3's sz 4.5y",
#  'express portofino blouse size m',
#  'new becca moonstone skin perfector',
#  "maurice's jeggings 1",
#  'american eagle girls boots size 1y',
#  'lularoe russian nesting dolls os htf',
#  'fleet foxes cd',
#  'bnib le morphe copper spice palette!!',
#  'black nude lace peep toe heals/pumps',
#  'lululemon minimalist tank',
#  "victoria's secret 5 pair panties size xl",
#  'vs 3pcs set love spell',
#  'vintage coach flats',
#  'gold chanel fashion wine marker charms',
#  'm 7/8 girls nwt dance danskin top',
#  'bundle for angelzlyne',
#  'victoria secret bag used',
#  'warning protect by bull terrier decal!',
#  'high waisted bikini swim suit',
#  'monster high minis wave 3',
#  'justice kids size 18',
#  'pink ranger movie figure hold',
#  'totoro wallet',
#  'california waves bikini',
#  'dooney & bourke madras shopper',
#  'oliver peoples jacey sunglasses polarize',
#  'ugly sweater medium',
#  'sale blunt razor cut bob lace part wig',
#  "minnetonka ankle women's boots sz 7.5",
#  'new with tags sz 4t outfit',
#  'dora the explorer movies',
#  'zubaz team leggings',
#  'michael kors selma medium handbag',
#  'silver bulk chain necklace',
#  'sally hansen sugar shimmer nail polish',
#  'red off shoulder romper',
#  'selene ugg',
#  'new! free shipping 1.5 oz banana powder',
#  'playskool tj bearytales read aloud',
#  'pro contour duo contour brush/palette',
#  'tactical led flashlight kit 1200 lumens',
#  'chanel lip bundle sale!!',
#  'nikon d3300 w/ 18-55 mm lens',
#  'vs pink oregon ducks sweats & top',
#  'sparkly "i do crew" tanks! new!',
#  'nike jordan retro 10 pink platinum 5y',
#  'pink pink pink! baseball cap hat.',
#  'victoria secret bikini bottoms size m',
#  'monster hall wall scrapbook kit',
#  'collectible tin - fossil watch',
#  "women's t-shirts l",
#  'girls hollister jeans size 3l',
#  'reserved listing for undrea',
#  'beautiful fringe coverup',
#  'free people rose moonshine sweater (l)',
#  '2 black bluetooth for nanny corner',
#  'ciaté nail polish advent calandra',
#  'roost turvy hummingbird hangout planter',
#  'under armor gym tote',
#  'vs pink 34a push up bra bundle',
#  'freeship crochet style toms shoes',
#  'bluetooth remote shutter selfie stick',
#  'vintage usa windbreaker - size xl',
#  'black butter slime 4oz',
#  'iphone 6 6s case wallet blue',
#  'ladies boutique 2x blouse set nwt',
#  'avantek hdtv antenna',
#  'baby girl winter suit',
#  'g1 transformers soundwave',
#  'new anastasia bh dipbrow pomade soft brn',
#  'kylie jenner lip kit in apricot',
#  '**sale** leather vince camuto boots',
#  'lularoe irma peacock feathers large nwt',
#  'cedar, white & blue sage smudge sticks',
#  'estée lauder resilience lift face creme',
#  'kids digital watch',
#  'nib simply vera heels',
#  'lularoe tc tiger floral leggings',
#  'on hold for abigail stitch funko pop',
#  'colourpop iluvsarahii chic-y palette',
#  'blue 3ds xl with 4 games on hold',
#  'links us smart wi-fi router',
#  "burberry weekend woman's spray",
#  'vintage life size doll. 61-62 yrs old.',
#  'kendal & kylie high waisted shorts',
#  'fighters uncaged for xbox 360 kinect',
#  'rae dunn wild and yasss mug',
#  '4 woodzeez families',
#  'lego city undercover - nintendo switch',
#  'benefit goof proof brow pencil no. 4',
#  'victoria secret pink: s razorback tank',
#  'medium orange lularoe irma',
#  '(2) for eight mobile phone/pop sockets',
#  'newborn onesie, bootie and mitten set',
#  'pittsburgh charm bracelet',
#  'lularoe stars and popsicles unicorn',
#  '2x for [rm] mix&match any kylie cosmetic',
#  'lot of 4 no boundaries lace boy shorts m',
#  'pandora pave sea turtle bead',
#  'bring me glass of wine socks',
#  'nwot disney jack skellington mini hat',
#  'syndicate xbox 360',
#  'black sport glasses like oakley kg',
#  'nwot vsx work out bra and matching capri',
#  'guns n roses keychain',
#  'pandora bow ring size 7',
#  "nike dri fit women's athletic shorts m",
#  'iridescent glitter bomb',
#  'monster high jane boolittle',
#  'my puppy barkley',
#  'bnwt nike sets',
#  '5 lanyard bundle ❤️ & 10 stickers',
#  'rare lularoe carol unicorn shirt bnwt',
#  'for henry only',
#  "women's nike comfort thong sandals",
#  'hot pink blazer size l',
#  "men's nike pegasus 89 brand new",
#  '7 hand sanitizers 2 cases',
#  'black swim suit top',
#  'nwt white banana republic blouse',
#  'qupid lace up pointed ballet flats',
#  "women's brown lacoste pique polo",
#  'huge sephora ipsy makeup bundle! all new',
#  'bareminerals loose powder eyeshadows',
#  'purple pen strip bow tie & hanky',
#  'mb',
#  '3c hares jordan infant',
#  'authentic dooney and bourke clear purse',
#  'black pink vs velcro sandals',
#  'treasure & bond boyfriend patch jeans',
#  'tarte tartelette in blood palette',
#  'authentic pandora glass bead',
#  'llr lularoe kids leggings s/m',
#  'free ship l pink tee shirt',
#  'star wars battlefront 2 game ps2',
#  '5th & ocean l.a. dodger ringer tee',
#  'nwot riot society jesus peace tye dye',
#  'lularoe tc dandelion black leggings',
#  'naked wardrobe greg midi dress',
#  '90s grunge shirt live vintage sz xl',
#  'nike vapor carbon 2.0 cleats',
#  'activated charcoal bundle for julia!',
#  'rainbow topaz white gold studs',
#  'new plus dress 2x lace up front',
#  'lose inches fast! sauna fat burning belt',
#  'm1chellel33 milani foundation',
#  'gap jacket 18/24 months',
#  'meander scentsy warmer(flash sale)',
#  'bundle for pren89',
#  'crochet coverup + flowy floral tank',
#  'greymint floam (4oz)',
#  'lularoe os walrus legging',
#  'navy pink long sleeve.',
#  'brand new tc americana leggings',
#  "pink victoria's secret sweat",
#  'lululemon presence of mind jacket size2.',
#  'funko pop bloody negan b&n exclusive',
#  'lululemon reveal crop',
#  'mermaid bundle for customer:)',
#  'michael kors bundle ~ purse & wallet',
#  '♥️ freeship cute top♥️',
#  'funko mystery mini iron man & hulkbuster',
#  '1981 pac-man patch',
#  'rae dunn dog canister only!',
#  'small nike shirt',
#  "m&m's brand coin sorter",
#  'gianni bini cork heels',
#  'jabra talk bluetooth',
#  'betsey johnson black cat earrings',
#  '1 new iphone and ipad charger',
#  'hold purchase ray-ban sunglasses',
#  'gillette simply venus razors, 4ct',
#  'cream knit choker',
#  "adidas men's golf shoe",
#  'rae dunn blessed mug [rm]',
#  'carousel of the sea figurines',
#  'the sims 3 late night expansion pc game',
#  '24 gold foiled notecards for sellers',
#  'eve pearl flawless face palette',
#  'rage against the machine vinyl record lp',
#  'french fries squishy',
#  'fluffybubbles',
#  '2 piece top and skirt set',
#  'bnwt free people top',
#  'mustela stretch marks prevention cream',
#  'vs pink lanyard w/id holder bundle(3)',
#  'b.b. king 45rpm vinyl record 7"',
#  "nwt men's volcom size 38 shorts",
#  'dutch bros tanks/tee',
#  'kylie jenner holiday addition mini kit',
#  'armani code 4.2 oz by giorgio armani',
#  "men's adidas techfit compression shirt m",
#  'gray sleeveless tshirt',
#  'ralph lauren skinny jeans 29 x 32',
#  'iphone 6/6s waterfall case - rain',
#  'the balm meet matte palette',
#  'new essential oil diffuser',
#  'black wolf',
#  'bcx girl skirt girls 16',
#  'farinaz taghavi blouse size 12',
#  'lot of madam alexander little woman doll',
#  'large maternity top',
#  'a&f light blue distressed jeans size 0',
#  'disney movies on dvd',
#  'vera bradley carry all bag',
#  'natural hip & butt enhancer lift',
#  'ce4 vape kits',
#  '2 bed skirts',
#  'pokemon gold',
#  'pol tank top',
#  "victoria's secret victoria tank top",
#  'nike racerback tank size l',
#  "men's puma running shoes 11.5",
#  'free ship! 5 love spell [rm] shipped',
#  'fleece cowl neck tunic hoodie',
#  'hermann',
#  'ipod 5 silver',
#  'targus laptop case',
#  'grey knit sweater brandy',
#  'figs and rouge hand cream',
#  'bnib bose soundlink bluetooth speaker',
#  'amethyst and 14k gold earrings',
#  'majic in the air bundle',
#  'h&m womens xs hoodie',
#  "victoria's secret no wire bra 34d",
#  'mic volume white earphones',
#  'wooden blocks bundle',
#  'pats',
#  'vintage floral top',
#  'rue21 floral baseball tee',
#  'baby boy receiving blankets',
#  'iphone 6s in pink 128gb',
#  'andy griffith seasons 3-5',
#  "new pandora disney's aurora charm set",
#  '10 3t girl pull up',
#  'xsmall nwt extreme crop',
#  "nike air force 1 '07 lv8 woven sz 9.5",
#  'lorac palette!',
#  'iphone 6s fre lifeproof case',
#  'funko gold naruto mini pop exclusive',
#  'tattoo kit free priority shipping',
#  '✨ kate spade wallet / makeup bag ✨',
#  'lego 30447 captain america motorcycle',
#  'free!! benefit gimme brow+ strobing',
#  'gold grillz',
#  '38-ddd victoria secret push up!',
#  'louis vuitton sullivan!',
#  'bundle this, cherokee coat, j&j raincoat',
#  "gold glitter it's a boy banner",
#  'freeship happy barkday dog toy',
#  'teens peacoat',
#  'ea ufc xbox one in great condition works',
#  'toddler backpack carrier',
#  'fossil leather cross body shoulder bag',
#  'bundle for dody',
#  'nintendo ghosts n goblins tested, clean',
#  'cherry vans size 9',
#  'glow kit reserved',
#  'jordan spizike big kids size 5',
#  'ck one calvin klein mixed media thong m',
#  '2 burberry lipstick reserved',
#  'donut popsocket and popclip',
#  'samsung 16gb smart choice micro-sdhc',
#  'leopard print tank size medium',
#  'wwe mattel basic brock lesnar figure',
#  'vintage raiders helmet coffee mug',
#  'baby gap jelly bow sandal ( size 9)',
#  '2t baby gap romper',
#  "victoria's secret lace up bikini top m",
#  'generic iphone earbud',
#  'authentic kylie lip gloss and metals',
#  'free ship nwt aztec crop top',
#  "lularoe kid's l/xl leggings",
#  'ruched club mini black holiday dress l',
#  'off the shoulder maroon l/s dress - m',
#  'x-men vs. street fighter- gambit & cammy',
#  'nike dri-fit black short-sleeve t-shirt',
#  'bundle tc reser',
#  '1m apple lightning usb cable 3ft charger',
#  'new too faced becca bare minerals lot',
#  'hatchimals hottest toy of 2016',
#  'large pink slippers',
#  'bed head large barrel curling iron',
#  'estee lauder sample size fragrances',
#  'new vs bikini 36 dd l fabulous',
#  'jumper bundle',
#  'drakengard 3 ps3',
#  'beautiful chain necklace with glass bead',
#  'foom magazine # 3. hold magic',
#  '25 inch blonde hair extensions',
#  'frogz stuffed toys',
#  'ipod touch, comes with case',
#  'yankee candle fresh cut roses large new',
#  'htc desire 626 phone cases',
#  'new victoria secret underwear bundle',
#  "club leon men's away soccer jersey large",
#  'contact cleaning solution peroxi clear',
#  'bn vs pink lanyard grey marl id case',
#  'black moon/sun tank - brandy melville',
#  'sexy red lace up choker',
#  'burton dryride snowboarding pants',
#  'luxury universal phone magnetic mount',
#  'black mesh g-string thong (new, sexy!)',
#  'small fox wallet',
#  'tanning bed lotion candy crush fixation',
#  'lace front small twist wig',
#  "l'oréal magic lumi primers",
#  'maybelline dream wonder powder',
#  'for dingdong',
#  'pamper size 4',
#  'ds lite (for parts)',
#  'pokemon stadium 2 nintendo 64',
#  'sailor moon choker',
#  'clinique foundation x3',
#  '4 piece grey tuxedo & shoes for frankie',
#  'lularoe mustard tc leggings! free ship!',
#  'barbie in the nutcracker dvd',
#  'light pink brandy melville low back top',
#  'sorel "joan of the arctic" waterproof',
#  'maroon and white long sleeve',
#  'brown sandal wedges | size 9',
#  'gymboree knit tights girls 6-12 mos nwt',
#  'rose case cover for lg k7 / tribute 5',
#  '27" dark brown one pc hair extension',
#  'vs beauty rush lip gloss bundle of 5',
#  'shimmer lights - blonde and silver',
#  'lily jade caroline brandy diaper bag',
#  'nw victoria secret black passport holder',
#  'mint green suit',
#  'marc jacobs toggles silver tone bracelet',
#  'bundle of infant girls swim suit 2t',
#  'white hangers- set of 8',
#  'galaxy slime kit',
#  '2x bundle for anurse4u2',
#  'white freeship earphones',
#  'vintage louis vuitton speedy 30',
#  'cc bag charms',
#  'silver elephant necklace',
#  'mascara testers',
#  'love pink pullover!!',
#  "michael kors watch women's",
#  'lavender wen conditioning shampoo w pump',
#  'skin solution cleaning system',
#  'nwt xs lularoe sarah solid gray',
#  'coach margot carryall',
#  'vintage lego land 6265 and 6260 bundle',
#  "men's polo hoodie size xxl",
#  'faux leather jacket forever 21',
#  '3x brand newpore cleaning sticks !!',
#  'vizio smart tv 24 inches',
#  'lego marvel super heroes (xbox 360)',
#  'new ballet lularoe leghings',
#  'mens under amour hoodie',
#  'dora backpack',
#  "i'm a nurse mug nwot",
#  'american eagle outfitters jegging 2 dark',
#  'off shoulder black top',
#  'vans unisex shoes',
#  'vtg levi highwaisted denim shorts 0',
#  'rimmel brow sculpting bundle',
#  'rae dunn selfie trinket tray desk decor',
#  'oversized burgundy sweater l',
#  'aeropostale xs sweater',
#  'hamilton mk handbag',
#  'snes donkey kong country super nintendo',
#  'rue 21 underwear bundle',
#  'new ae aerie bralettes lot of 3',
#  "sketchers twinkle toes- girl's size 12.5",
#  'pink copper metallic tote bag nwt',
#  'desi perkins quay high key gold',
#  'vans checker print',
#  'mood dragons',
#  'gel-a-peel design station-brand new',
#  'bluetooth watch works best with android',
#  "women's north face denali jacket xl",
#  '5 vs lip glosses',
#  'pokemon game bundle on hold',
#  '(m) nwt vs pink hawaii bling long tee',
#  '1pk aaa energizer recharge power plus.',
#  'medium floral polka dot nicole',
#  'ralph lauren hat kids 4-7',
#  'eeyor quote heart charm necklace',
#  'rae dunn caffeine not yours mugs',
#  '(100) 4"x8" poly bubble mailers on sale!',
#  'nwt planet blue exile dress',
#  'vintage style wifey tshirt',
#  'victoria secrets pink bras',
#  'cute hawaiian top',
#  'sailor moon black hat yellow moon',
#  'legion of collectors funko krypto shirt',
#  'gorgeous lularoe unicorn maxi xs small s',
#  "victoria's secret xl short yoga pant",
#  'sparkle red dress',
#  "women's crocs flip flops new",
#  "kylie valentine's minis•read below",
#  'xl lularoe cassie new with tags!',
#  "where's waldo costume",
#  'silver cz bracelet',
#  'white/pink vanity kit (holding)',
#  'bundle for rico josh',
#  'temptu liquid glow & crown contour brush',
#  'lularoe hot pink irma xxs',
#  'case for macbook pro 13 a1278 black',
#  'tank tops gap, hollister, and cruel girl',
#  "levi's vintage 550 mom jeans",
#  'blue chaps vest xl',
#  'reserved for juliee100',
#  'demin dress/shirt',
#  '20 pcs! 10 pcs bare lift 10 pcs covers',
#  'nice beautiful lights with nice picture',
#  'lancôme new creme',
#  'kids hurache',
#  'eight cards for new baby',
#  'miche luxe cover with handles',
#  'bundle of 5 tshirt 2 free',
#  'brand new red nike pros',
#  'x2 benefit hoola lip gloss',
#  'eureka- eur71b',
#  "women's 2x hoodie",
#  'air jordan 6 retro maroon men size 12',
#  "pink victoria's secret lot nwt",
#  'light brown top ~ vizio',
#  'bnwt newborn holiday dress',
#  '12 pc professional lip/eyeliner pencils',
#  'lego dimensions microsoft xbox one game',
#  'american eagle soft & sexy tank size s',
#  'jack spade case for iphone 7 plus',
#  'canon pixma printer ink black & color',
#  'vintage bracelets and matching ring',
#  'rae dunn christmas elf platter',
#  'space jam tune squad lola bunny outfit',
#  'segway mini pro by ninebot',
#  'girls size 6 pants lot',
#  'rae dunn mixing bowls mix dash and pinch',
#  "'starry eyed' loose glitter",
#  'pacsun olive green slit top',
#  'zara synthetic leather aviator jacket',
#  'hard plastic water bong',
#  'handmade native american earrings',
#  'cute korean travel nail clipper',
#  '2 ipod shuffles apple',
#  'tory burch crystal pearl drop earrings',
#  'tastefully simple chili blend and marina',
#  'for theboysmom',
#  'facial mask and scrub bundle',
#  'retro 9 anthracite',
#  'enfamil a.r. formula free shipping',
#  'vs pink long sleeve t-shirt',
#  'iphone/wallet pink case',
#  'express button down/ essential shirt',
#  'kylie ginger lipkit',
#  'nike air max 8',
#  'american eagle stretch jeans skinny jean',
#  'nwot sienna necklace',
#  'lululemon salutation to savasana tank',
#  'i bloom penguin squishy',
#  'kenneth cole black shoulder purse',
#  'purple butterfly jewelry earring holder',
#  '*free ship* vs push up bra',
#  "men's ray band glasses",
#  "victoria's secret pink sleep shirt, sz l",
#  '0g iridescent gem plugs',
#  'bundle for kobe',
#  'track leggings',
#  'democrat ornament',
#  'kate spade sunglasses + black ks bangle',
#  'shade and light contour brush',
#  'rebecca minkoff heels 7 (worn twice)',
#  'lularoe medium azure, nwt',
#  '100% real mexican silver. bundle',
#  'too faced pretty rebel pallete',
#  'coral 38dd bra-reserved',
#  'festive & warm 36" leaves tablerunner',
#  'genuine diamond heart ring',
#  'new,(14/16 kids/xs ladies)workout capris',
#  'mini boden size 5/6',
#  'nib beautiful peacock pendulum clock',
#  'beautiful door hanging hold for robin',
#  'lularoe purple xxs irma top only',
#  'highlighter by beauty creations',
#  'free shipping for miss linda',
#  'kuhl cargo gray women pants 6',
#  'bratz lttle 4 becky',
#  'ncaa football 14 for xbox 360',
#  'thrasher flames tee',
#  '(xs) athleta joggers!',
#  'tarte amazonian clay dual eyeliner',
#  'hugo buscati collection summer dress',
#  'gap long sleeve cardigan size xl',
#  'boys black nike pullover',
#  'lot of dice 20 dice',
#  "scuba men's wet suit xxl",
#  'pink vs campus tee sz s',
#  'newborn slip-ons',
#  'bonnet 6-12 on hold for bundle',
#  'eyes & lips',
#  'yes to grapefruit pore perfecting peel',
#  'vs pink socks ❗️price drop❗quick-catch',
#  'tommy hilfiger polo small',
#  "victoria's secret pink thermal pj set",
#  'jordan size 6',
#  'bath & body works scented candles',
#  '16g captive bead',
#  'new••revlon ultra matte lip color',
#  'peacock/blueberry pie matte lipgloss',
#  "victoria's secret hold for ashley",
#  'metal candle sticks',
#  'casemate brilliance tough case for 6/6s',
#  'bright hold',
#  'steve madden hipstr bootie tan sz 8',
#  'nabi charger.',
#  'brand new lip exfoliating lipstick',
#  'bnwt vs pink campus pants black m',
#  'fashion monogrammed handbag',
#  'sperry flats',
#  'hold for juanita',
#  'nightmare foil mtg',
#  'ks jana bracelet',
#  'nwt weekender half zip la playa',
#  'turquoise mermaid blanket',
#  'lipsense fire n ice starter kit',
#  'jeffrey campbell taggart booties',
#  "wm's shirt 3x",
#  'reserved for kindred kitty stickers',
#  'micheal kors watch woman',
#  'amazing nature tropical paradise puzzle',
#  'wifi laptop/car sticker.',
#  'vera bradley lanyard and pouch',
#  'mario party 7 for gamecube/ wii with mic',
#  'lush magical moringa moisturizer new',
#  'dr. martens air wair girl boots size 8c',
#  'obagi 3 nuderm clear x 2',
#  'denver broncos scarf & gloves set',
#  'lularoe julia print leggings os',
#  'hollister high neck top',
#  'bebe brand new shorts size xs',
#  'hold 3.75" cloudy red donut glass pipe',
#  'nyx flirty lip set nib',
#  'kindle - ipad mini case',
#  'set of 2 vs noir mists for nikki',
#  'nude booties size 8',
#  'bright knit sweater',
#  'rimless diamond shape clear glasses',
#  'dare black neon halter crop top sm 90s',
#  'brush belt',
#  'kkw creme liquid lipstick 4 pc set',
#  "polo ralph lauren men's!",
#  'estée lauder double wear powder 1w2 sand',
#  'new os lularoe cupcake leggings',
#  '27 item urban decay no. 7 philosophy [rm]',
#  "lot of men's clothing",
#  "new women's pugsgear kiss baseball hat",
#  'jojoba coconut oil scalp conditioner',
#  'youth girls fringe boots sz3',
#  'charro child costume w/ hat & boots',
#  'kate spade wallet "stacey slim"',
#  'vera bradley checkbook cover canterberry',
#  'rip and dip shirt',
#  'victoria secret pink ultimate legging',
#  "women's 2 lululemon jackets for sunshine",
#  'nautica stitched logo shirt fits like xl',
#  'hawaii barbie',
#  'la prairie skincare set',
#  'pop! paige figure',
#  "baby's first year [rm] w/ baby purchase",
#  'tie up crop top',
#  'lularoe tc santa holiday christmas nwt',
#  'boys christmas outfit',
#  'vs pink campus tee long sleeve top',
#  'gimmicks tank for ncoovert',
#  'nwt bebe body con dress',
#  'bitty baby underwear',
#  'carters baby hooded towels and moccasins',
#  "medium daddy's little monster shirt",
#  'bundle for one step forward',
#  'funko pop football',
#  'maternity support bands',
#  'kylie cosmetics holiday kyshadow',
#  '♡ 1 pip boy fallout 4 patch ♡',
#  'double wear & mac lipstick',
#  'loft light pink blouse',
#  'nip vs pink sports bra m. $firm',
#  'funko pop grey lighting mcqueen',
#  "sm victoria's secret pink sports bra",
#  'mk juliana 3 in 1 wallet baltic blue',
#  'gigi mini pro waxing kit',
#  'guess who? disney edition',
#  'alfani faux leather draped front cardign',
#  'new ♡ polo ralph lauren tote/purse',
#  'happy feet. blu-ray',
#  'ariat zebra boots',
#  'stride rite boys shoes on hold',
#  'samsung usb travel charger',
#  'disneyland jack light up necklace',
#  'lace front grey ombré wig (20 inches)',
#  'aaron hernandez football card',
#  'express editor ankle',
#  'disney mickey mouse maternity shirt xl',
#  'webkinz signature dutch bunny',
#  't10 mini fully loaded kodi preinstalled',
#  'like new hamilton beach coffee grinder',
#  'six piece matteify matte lipstick set',
#  'too faced le grand chateau set',
#  'large perfect t reserved for mendi',
#  "new! men's geneva oversize fashion watch",
#  'the balm bahama mama bronzer 0.02oz',
#  'preppy nautical striped print scarf',
#  'nike pro 7/8 warm training tights',
#  '⚡⚡sale! white crop top',
#  "harley davidson men's large t shirt",
#  'anthropologie leifnotes sz s tank',
#  'variety of action figures',
#  "felisip00's bundle",
#  'cooking buddy towel/pot holder',
#  'new vs pink platinum grey hat',
#  'lane bryant brand new sz 26/28',
#  'holiday 10$ bundle ❤️',
#  'toddler boy tennis shoes size 10',
#  'holiday barbie 2008',
#  'triangle hair clip bundle',
#  "puma boy's ls shirt size 6 nwt",
#  "women's winter jacket zeroxposur",
#  '3 brand new 1800puffs disposable e-cigar',
#  '3 new juicy couture mini perfumes',
#  'sexy lace up velvet bodysuit',
#  'dose of colors-stone',
#  'sterling s925 bangle 3 charm bundle',
#  'nike dri fit capri pants',
#  'free ship! geisha costume',
#  'womens keds shoes sz 9.5 arch support',
#  'vineyard vines kentucky derby hat',
#  'propel micro drone',
#  'black sequin swimsuit',
#  'free people boho hippie tank top',
#  'stila magnificent metal glitter',
#  'tula prance dark purple solid new',
#  'nwt short and long sleeved pink shirts',
#  '14g nipple jewelry piercings',
#  'floral kimono w/ pockets',
#  'os leggings - lularoe - fall leaves',
#  "men's pacsun bullhead joggers",
#  'essential oils! samples and free gifts!',
#  'lularoe small s teal sarah',
#  'funko cornish pixie gryndlow mandrake',
#  'on sale cheapest 30 oz yeti rambler pink',
#  'air jordan 11 retro 72-10 kids',
#  'lucky brand lil maggie flare size 6/28',
#  'fashion nova rose top',
#  "under armour men's ls shirt 3xl",
#  'wwe elite action figures all 4',
#  'self-inflating sleeping pad with pillow',
#  'new cross body thirty one bag',
#  'kylie jenner logo t-shirt',
#  'silver pumps',
#  'funko pop daredevil #214/gb papper boy',
#  'clear holo putty',
#  'brand new train set',
#  'brown henna/mehendhi tattoo cones',
#  'loreal eyeshadow',
#  'lemon / orange squeeze',
#  'new big bucks tank top',
#  'butterfly & hearts ring *free shipping*',
#  'cute little céline bag',
#  'lularoe floral tc leggings flowers',
#  'star wars wookiee chewbacca knit hat',
#  '2 women shirt size 1x 18/20w',
#  'bundle for mamaxbear',
#  'hollister shorts socal size small',
#  'rock tape (orange color) sports tape',
#  'lime crime nude shades small size',
#  'pumas & adidas- reserved for ben',
#  'love❤pink❤socks ❤colors may repeat/vary',
#  'new gray puma trainers(size7)',
#  '2 new plush bubble guppies',
#  'nwt aritzia babaton charles bodysuit xs',
#  '12 pairs sparkly stud earrings!!',
#  'mew plush',
#  'blouse by sweet magnolia',
#  'euc ult mesh yogas xs',
#  'medium lularoe perfect tee nwt',
#  'nwt- kate spade stacy wallet',
#  'professional nail drill mm-25000',
#  'for brandon!',
#  'butt lift wax jeans',
#  '❣️sale black clear aviator glasses',
#  'air jordan red retro long sleeve tshirt',
#  'pure radiance candle',
#  'alex and ani energy star fish bracelet',
#  'llr os russian dolls leggings',
#  'marvel legends spiderman *free shipping',
#  'nike red sweater',
#  'bundle chanel black handbag + jacket',
#  'brandh melville & vineyard vines sticker',
#  'uzi chain necklace new',
#  'reserved for raeexmz',
#  "puma roma woman's",
#  '7.5, 9 or 9.5 nike metcon 2 women new',
#  'beats headphones!',
#  'youth under armour hoodie & nike hoodie',
#  'custom for mary kiss',
#  'sega game gear lot of 4 new sealed',
#  'lot of 100 pokémon card guaranteed ex',
#  'clear hard iphone 7 plus case +glass',
#  'bnib le mac objects of affection gold',
#  'chanel cc shirt small',
#  "men's silver and gold errings combo",
#  'vintage pearlized rhinestone band size 5',
#  'premier designs bangle set',
#  'vs knit onesie',
#  '2 x burberry polo shirt for jramirez',
#  'brandnew slouchy pink crew',
#  'so tee shirt bundle lot',
#  'mossimo gray leggings workout pants',
#  'certified iphone 5 6 charger cable',
#  '3xl cassie and 3xl classic tee',
#  'lady gaga & katy perry perfumes',
#  'britax b-ready 2nd seat double back',
#  'gwen. holdmarilyn monroe quote necklace',
#  'boho cotton on floral romper',
#  'vs strappy back front close bra',
#  '6 girls nwt nike hyper pink short fr shp',
#  'retro le coq sportif pullover sweatshirt',
#  "burberry women's summer halter - xs",
#  'build a bear bundle plus star wars',
#  'reserved andica*',
#  'free people tree swing tunic sleeveless',
#  '6 pairs eyelashes',
#  'jennifer lopez black heels 5.5 m 3 inch',
#  'starwars swimsuit',
#  'for skittles dove shampoo & conditioner',
#  'air jordan retro 5 "grape" size 9.5',
#  '1 hour intense teeth whitening kit',
#  'new tc smoke blue lularoe leggings',
#  'ds bundle (pink, blue, + red) lot',
#  'black and decker electric saw',
#  '10 piece makeup brush set ♡',
#  'kids salt water shark sandals',
#  'miranda lambert style texas tank top',
#  'face mask fleece balaclava winter hat',
#  "girl's nike shorts",
#  'borelli size 2 1/2 y',
#  'baby girl sperry top sider shoes sz 7',
#  'sarah.',
#  'new dream catcher with feathers',
#  "2 pairs torrid embellished jean's 18w",
#  'new lularoe mommy & me leggings s/m & tc',
#  '"always on vacay" swimsuit size large',
#  'anastasia creme contour kit',
#  'mascara ! blush ! highlight !',
#  'mossimo size 8 abstract capri pants',
#  'old navy maternity capri leggings grey',
#  'lularoe os fox foxes leggings',
#  'nwot os black & white swirl legging',
#  'cool pad android phone',
#  'baby toy (good for shopping cart)',
#  'brandy melville tati dress nwt',
#  'loreal voluminous butterfly intenza',
#  'new estée lauder 1w1 bone double wear',
#  'instawave auto curler',
#  't-shirt bundle 3t*sold*',
#  'discovering the life span',
#  'super cute long tunic nwot 4x',
#  'sz7 gold filled emerald w/box',
#  'nike air jordan 8 retro size 3c infant',
#  'rae dunn salt/pepper',
#  'original christmas classics dvd set',
#  'vs angels 34d demi',
#  'under armour 18 months girls',
#  'vs sweatpants & cardigan',
#  "men's g-star raw denim",
#  'bnwt xl randy',
#  'vic firth stickers !',
#  'american living purse',
#  'set of 3 sports bra danskin size 2x',
#  'insurgent bluray + dvd',
#  'jaclyn hill champagne pop poured crème',
#  'nike dry fit tank top',
#  'canon battery charger cb-2ly',
#  'nwt l crew tee & shorts outfit vs pink',
#  'live fast die pretty metal mulisha',
#  'plw iphone 6plus case.',
#  'vintage floral necklace',
#  'torrid tank top 4x',
#  'bundle for anniq',
#  "victoria's secret swimsuit one piece",
#  '14k white gold plated figaro chain',
#  'kendra scott royal blue opal dani [rm]',
#  'lot 2 pair men\'s shorts black, blue 36"',
#  'vintage fendi',
#  'american eagle shorts hold for natasha_a',
#  'black tween leggings',
#  'nyc by perlina shoulder bag',
#  'pink silky pajamas',
#  'england 2016 away soccer jersey',
#  'converse shoes sz 9',
#  'brand new pokémon cards just in',
#  'book of mormon playbill w/ gavin creel',
#  'nike free bhm reserved for lowteesavage',
#  'bandolino broadenf black leather',
#  'black and white nike baseball sleeves',
#  'yugioh cards for cota',
#  'euc lularoe paratrooper set',
#  'set of two tee-shirts',
#  'chaps swim trunks',
#  'dye navy top',
#  'gold body chain from h&m',
#  'grey whale pocket tee - free ship',
#  'old navy vest for girls size s',
#  'urban decay razor sharp liq. eyeliner',
#  'mickey mouse 1st bd banner',
#  'kendra scott jana link bracelet',
#  'new! 3-piece toddler girl outfit',
#  'guilty gucci',
#  'it stephen king shirt medium clown dvd',
#  'suede button up express shorts',
#  'nike pro fitted long sleeve size small',
#  'big shirt cover up.',
#  'free ship! s playboy bunny pj top',
#  'proactiv complexion perfecting hydrator',
#  'stoner advisory logo glass jar',
#  'vs bra bundle 32dd',
#  "sz.m women's nike top",
#  'rae dunn bowl (*choice - each*)',
#  '3xl lularoe flag randy',
#  'rainbow fluff',
#  'aztec keyhole top',
#  '12 glitter eyeliner pens',
#  'new 2 colgate optic white toothpaste',
#  'denim skinny jean overalls',
#  'gap scoopneck black sweater',
#  'milana eyelash serum',
#  'monoreno boho gypsy ruffle shift dress',
#  'king size 3 pcd blanket set',
#  "very sexy for her by victoria's secret",
#  'lola tampons',
#  'vs double banded bikini bottom',
#  'maxi tube top dress',
#  "bundle levi's and columbia",
#  'lularoe sarah l red floral cardigan',
#  'lularoe halloween, where the wild things',
#  'high quality sterling silver ring size 9',
#  'nike drifit shorts (m)',
#  'freeship new lularoe planet leggings',
#  'mally beauty ultimateperformance-med tan',
#  'pink purse charm ✨',
#  'ny & co teal infinity scarf',
#  'off the shoulder stripe top',
#  'mossimo gray wedges',
#  'minifigure and brick silicone mold set',
#  'victoria secret bride tank top size l',
#  'nintendo ds red',
#  'new era sf giants cap',
#  'nfl seahawks seattle lanyard',
#  'listing for lucy hernandez',
#  'periwinkle prom dress',
#  'nwt men nike medium zip up',
#  'guess silver and pink flower watch',
#  'sephora ombre obsession blush palette',
#  'kate spade bag!!',
#  "xs women's or xl girls 12/14 denim top",
#  'lularoe camo leggings. os',
#  'two stocking holders',
#  'girls t-shirts',
#  '50+ lot of euro beads charms nwot',
#  'lularoe classic t shirt size 3xl',
#  'pink zebra glimmer candle lot new',
#  'rare vs pink storage tin',
#  'ugg grey/metallic cardy sweater boots',
#  'strawberry lemonade scented candle bars',
#  'pure barre 3/4 sleeve. small',
#  'athleta pleated skirt/skort! sz 14',
#  "nike women's blazers high",
#  'piyo workout dvd',
#  'rare converse',
#  'yankee candle vent sticks and coupon',
#  '•free ship• adidas detroit pistons shirt',
#  'flowy printed shorts',
#  'lularoe os feathers!!',
#  'hungry caterpillar cloth diaper',
#  'tony moly bronzing glam',
#  'vs pink zip hoodie sweat shirt -s',
#  'small cassie lularoe ufo',
#  'galaxy s7 phone case with card holder',
#  'lot of high end samples & deluxe samples',
#  'bnwt nike pro dri-fit shorts xl',
#  'lot of 4 intellivision games negotiable',
#  '+ by ed sheeran vinyl lp',
#  "bundle for laney's treasures",
#  'watermelon bathing suit for 18mth girl',
#  'true religion women 27',
#  'huge lot of lps',
#  'lululemon running tights',
#  '14k solid white gold xoxo necklace',
#  'polo ralph lauren suede boots size 11',
#  'brand new febreze unstoppable bundle',
#  '2 nike dri-fit white/pink sz xs bundle',
#  'too faced blushing bronzer',
#  'bath & body works aromatherapy body wash',
#  'blue crystal pronged belly button ring',
#  'primtive bundle for crazydays',
#  'army studded wallet',
#  'quick sale! free ship llr neon arrows!',
#  'non-american girl cinderella dress',
#  "women's new skinny jeans",
#  'classic 2xl lularoe',
#  '5 nivea in-shower body lotion',
#  'toms desert wedges little girl',
#  'marc jacobs laptop case',
#  'tie dye crew neck shirt',
#  'kylie exposed and leo mini',
#  'becca hill champagne collection#2',
#  'bundle for tessa!',
#  'vs pink cotton bra',
#  'black workout tank top',
#  'mint orca lularoe leggings',
#  'michael kors ring gold',
#  'black and bronze nike lanyard',
#  'lularoe xs classic and os leggings',
#  'new boys nike shirt large 14/16',
#  'gorgeous lularoe large julia!',
#  'cincinnati reds billy hatcher',
#  'hp office jet 951 xl magenta',
#  'willow tree angel duo',
#  '32d aerie bra bundle',
#  'fs sinister dvd',
#  'boys jeans size 8',
#  'tommy hilfiger wallet **nice**',
#  "victoria's secret nightie large",
#  'consuela hand bag',
#  'american girl merry magenta set',
#  'baby gap dress 12-18 month nwt',
#  'patagonia synchilla snap t xs men',
#  'tapestry chill tree',
#  'new paisley lularoe os leggings',
#  '2 pink t- shirts!!',
#  'lularoe small black irma bnwt',
#  'kerastase bundle 1+ 1',
#  'jessica simpson - sunglasses',
#  'lululemon wamo camo crb racerback tank 6',
#  'bundle for babycee',
#  'robin (batman) costume sz 6',
#  'flash sale! clinique lipstick and liner',
#  'free ship ~ lg sexy skirt',
#  'reserved for alicia* f60 & f70',
#  'sephora:mermaid tail eyeshadow -reserved',
#  '2 maybelline volume express mascara',
#  'lularoe rare green feather set',
#  'reebok & nike spanks / shorts',
#  'north face girls jacket toddler 5',
#  '3/4" moondevite plugs',
#  '5 bounce dyer sheets',
#  'pandora mermaid charm',
#  'lularoe sarah large black and cocoa',
#  'juniors hi low burnt orange dress',
#  'atlanta braves national league jersey',
#  'columbia winter ski coat wm s',
#  'tarte swamp queen palette authentic',
#  'women m thin jogger type of pants',
#  'vs pink sports bra bundle. small',
#  'pokémon snap& 2 nintendo 64 memory cards',
#  'fs supergoop city sunscreen serum lot x3',
#  'bridal robe',
#  'pink cheetah juicy couture tote',
#  'brandy melville ringer tee set',
#  '3ds xl hard glitter covers nwt',
#  'new s vs pink perfect full zip hoodie',
#  'fairytopia barbie',
#  '5 similac advance',
#  'goodfellas dvd movie',
#  'bath & body works lotion & travel spray',
#  'black capri athletic pants',
#  'black and grey long sleeve dress',
#  "women's michael kors watch(rose gold)",
#  'victoria secret pink 86 jersey hoodie',
#  'toddler nike sz 8',
#  'pandora princess ring! size 5',
#  'vs pink gators sweatpants',
#  'mac limited edition lipstick riri woo',
#  "vguc women's toms red size 7.5",
#  'usmc camo green tshirt',
#  'car charger & earphones & charger',
#  'bundle for kim quesenberry',
#  '11x4 farmhouse wooden sign',
#  'free ship pyt argan oil',
#  'brand new bath and body works perfume',
#  'heather gray roxy knit cardigan',
#  '4 laura 2 ken cole,9 west, floral neckla',
#  'michael michael kors sandals',
#  'michael kors ritz bracelet watch mk5676',
#  'green navy pink lularoe os leggings',
#  'makeup forever hd microperfecting primer',
#  'pac man fever',
#  'nwt large pink slides',
#  'fsu seminoles spirit jersey nwt',
#  'gold skinny hoops',
#  'new micro usb 3in1 data sync charger otg',
#  'lot baby boy pants 0-3 month',
#  'infallible foundation 306 & 309',
#  ...}

# %% [markdown]
# # Mercari Price Prediction

# %%
import category_encoders as ce
import feature_engine.encoding as fe
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import QuantileTransformer
from sklearn.preprocessing import PowerTransformer

from sklearn.pipeline import Pipeline

import sklearn.metrics as metrics

# %% [markdown]
# ## Pytorch Lightning

# %%
dd_validation = pytorch_dataset.build_test_dataset(dd_train, validation)
# Out:
# target: price_log
# train: 1185328
# test: (296333, 16)
# test set mode
# => target encoding
# => numerical encoding
# => categorical encoding
# name vocabulary size 104570
# item_description vocabulary size 184473
# name vocabulary size 455
# item_description vocabulary size 995
# target min, max range (-2.7831687470788093, 4.21270471801917)

# %%
model = pytorch_model.PytorchModel.load_from_checkpoint(checkpoint_path= os.path.join(model_dump_path, model_file))
# Out:
# "categorical_embedding_dropout":   0.4
# "categorical_embedding_size":      [(6, 4), (4522, 178), (12, 6), (115, 23), (866, 71)]
# "char_bidirectional":              False
# "char_embedding_dimension":        40
# "char_recurrent_hidden_size":      50
# "char_recurrent_layers":           1
# "char_rnn":                        LSTM
# "char_vocabulary_size":            {'name': 455, 'item_description': 995}
# "final_linear_layer":              True
# "final_normalization":             False
# "is_target_log":                   True
# "learning_rate":                   0.001
# "linear_layer_activation":         ReLU(inplace=True)
# "linear_layer_normalization":      BatchNorm1d
# "linear_layer_skip_connections":   (3, ([1024], [0.3]))
# "linear_layers":                   ([512], [0.2])
# "loss_function":                   MSELoss()
# "metric_to_monitor":               rmsle
# "normalization_before_activation": True
# "numerical_batch_normalization":   True
# "numerical_input_size":            5
# "optimizer":                       Adam
# "pretrained_hparams":              False
# "target_encoder":                  PowerTransformer(method='box-cox')
# "target_range":                    None
# "text_as_embedding_bag":           False
# "text_as_embedding_bag_mode":      mean
# "text_bidirectional":              True
# "text_embedding_dimension":        50
# "text_recurrent_hidden_size":      100
# "text_recurrent_layers":           2
# "text_rnn":                        GRU
# "text_vocabulary_size":            {'name': 104570, 'item_description': 184473}
# "verbose":                         True
# processing text
# processing chars
# sizes detailed: [['cat: 282', 'num: 5', 'text: 400', 'char:100'], 'skip: 1024', 'lin: 512', 1]
# sizes: [787, 1024, 512, 1]

# %%
model
# Out:
# PytorchModel(
#   (metric): MeanSquaredError()
#   (loss_function): MSELoss()
#   (embeds): ModuleList(
#     (0): Embedding(6, 4, padding_idx=0)
#     (1): Embedding(4522, 178, padding_idx=0)
#     (2): Embedding(12, 6, padding_idx=0)
#     (3): Embedding(115, 23, padding_idx=0)
#     (4): Embedding(866, 71, padding_idx=0)
#   )
#   (categorical_dropout): Dropout(p=0.4, inplace=False)
#   (batch_normalization_numerical): BatchNorm1d(5, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (text_embeddings): ModuleList(
#     (0): TextRecurrentLayer(
#       (embedding): Embedding(104570, 50, padding_idx=0)
#       (rnn): GRU(50, 100, num_layers=2, batch_first=True, bidirectional=True)
#       (last_time_step): LastTimeStep()
#     )
#     (1): TextRecurrentLayer(
#       (embedding): Embedding(184473, 50, padding_idx=0)
#       (rnn): GRU(50, 100, num_layers=2, batch_first=True, bidirectional=True)
#       (last_time_step): LastTimeStep()
#     )
#   )
#   (char_embeddings): ModuleList(
#     (0): TextRecurrentLayer(
#       (embedding): Embedding(455, 40, padding_idx=0)
#       (rnn): LSTM(40, 50, batch_first=True)
#       (last_time_step): LastTimeStep()
#     )
#     (1): TextRecurrentLayer(
#       (embedding): Embedding(995, 40, padding_idx=0)
#       (rnn): LSTM(40, 50, batch_first=True)
#       (last_time_step): LastTimeStep()
#     )
#   )
#   (linear_layers): Sequential(
#     (0): SkipDenseConnection(
#       (activation): ReLU(inplace=True)
#       (skip_layers): ModuleList(
#         (0): LinearNormDropActivation(
#           (0): Linear(in_features=787, out_features=787, bias=False)
#           (1): BatchNorm1d(787, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Dropout(p=0.3, inplace=False)
#         )
#         (1): LinearNormDropActivation(
#           (0): Linear(in_features=787, out_features=787, bias=False)
#           (1): BatchNorm1d(787, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Dropout(p=0.3, inplace=False)
#         )
#         (2): LinearNormDropActivation(
#           (0): Linear(in_features=1574, out_features=1024, bias=False)
#           (1): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Dropout(p=0.3, inplace=False)
#         )
#       )
#     )
#     (1): LinearNormDropActivation(
#       (0): Linear(in_features=1024, out_features=512, bias=False)
#       (1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Dropout(p=0.2, inplace=False)
#     )
#   )
#   (final_layer): Sequential(
#     (0): LinearNormDropActivation(
#       (0): Linear(in_features=512, out_features=1, bias=True)
#     )
#   )
# )

# %% [markdown]
# ## Try manual input/output

# %%
model.sizes
# Out:
# [787, 1024, 512, 1]

# %%
hidden_layer_size = model.sizes[0]
hidden_layer_size
# Out:
# 787

# %% [markdown]
# ## Test Set Hidden Layer (Concatenated Layer)

# %%
product_emb_hidden_test = utils.get_product_embeddings_from_hidden_layer(model, validation, dd_train, hidden_layer_size = hidden_layer_size, item_column="name")

# %%
product_emb_hidden_train = utils.get_product_embeddings_from_hidden_layer(model, train, dd_train, hidden_layer_size = hidden_layer_size, item_column="name")

# %% [markdown]
# ## Similarity using Hidden Layer Representation

# %%
search_product = "speacker"
search_product

product_index = validation[validation["name"] == search_product].index.to_list()
product_index
# Out:
# [236399]

# %%
product_name = search_product
cos = cosine_similarity(product_emb_hidden_train["matrix"], product_emb_hidden_test["product2vector"][f"{search_product}_{product_index[0]}"].reshape(1, -1))
print(cos.shape)
top_n = np.argsort(cos, axis=0, )[-10:][::-1].reshape(-1)
top_similarity = cos[top_n].reshape(-1)
print(top_n, top_similarity)
# Out:
# (1185328, 1)
# [ 260223  794340  844688  185231   79511  840326  512089 1125664  544490
#   468422] [0.7802913  0.77537956 0.76305055 0.76202467 0.75976259 0.75414294
#  0.75188236 0.75011927 0.7453418  0.74497159]

# %%
tmp = validation[validation["name"] == search_product]

html = tmp[["name", "item_condition_id", "category_name", "brand_name", "shipping", "item_description", "is_brand_missing", "price"]].to_html(classes='table table-stripped')
text_file = open(f"{search_product}_search_hidden_layer.html", "w")
text_file.write(html)
text_file.close()

tmp
# Out:
#             id      name item_condition_id                                                    category_name brand_name  shipping item_description  desc_len  name_len subcategory_1             subcategory_2               subcategory_3  is_brand_missing  is_item_description_missing  price  price_log
# 236399  232689  speacker                 1  Electronics/TV, Audio & Surveillance/Home Speakers & Subwoofers    missing       0.0    pink speacker       2.0       1.0   electronics  tv, audio & surveillance  home speakers & subwoofers               1.0                          0.0   11.0   2.484907

# %%
train[train["name"] == search_product]
# Out:
# Empty DataFrame
# Columns: [id, name, item_condition_id, category_name, brand_name, shipping, item_description, desc_len, name_len, subcategory_1, subcategory_2, subcategory_3, is_brand_missing, is_item_description_missing, price, price_log]
# Index: []

# %%
from IPython.display import HTML
tmp = train.iloc[top_n].copy().assign(similarity = top_similarity).head()[["name", "item_condition_id", "category_name", "brand_name", "shipping", "item_description", "is_brand_missing", "price", "similarity"]]
html = tmp.to_html(classes='table table-stripped')
text_file = open(f"{search_product}_hidden_layer.html", "w")
text_file.write(html)
text_file.close()

tmp
# Out:
#                            name item_condition_id                                                    category_name brand_name  shipping                                                                                                                                           item_description  is_brand_missing  price  similarity
# 260223       waterproof speaker                 3  Electronics/TV, Audio & Surveillance/Home Speakers & Subwoofers    missing       0.0                                                                                                                                    perfect for the shower!               1.0   14.0    0.780291
# 794340         light up speaker                 1  Electronics/TV, Audio & Surveillance/Home Speakers & Subwoofers    missing       0.0                                     light up bluetooth speaker loud and works great great condition lights up in many different colors really entertaining               1.0   11.0    0.775380
# 844688  wireless shower speaker                 1  Electronics/TV, Audio & Surveillance/Home Speakers & Subwoofers    missing       0.0  aqua sound wireless shower speaker you can: answer/end calls built in mic for calls speaker bluetooth hookup to play music from your phone new never used               1.0   11.0    0.763051
# 185231           water speakers                 2  Electronics/TV, Audio & Surveillance/Home Speakers & Subwoofers    missing       0.0                                                                       comes with plug for the wall and aux cord used maybe once just sitting on my dresser               1.0   14.0    0.762025
# 79511               google home                 1  Electronics/TV, Audio & Surveillance/Home Speakers & Subwoofers    missing       0.0                                                                                                         never used only taken out of the box has the cord.               1.0   71.0    0.759763

# %%
import joblib
product_similarity_emb_hidden = {'train': train, 'test': validation,
                      'product_train_embedding_matrix': product_emb_hidden_train["matrix"], 
                      'products_test_vector_dict': product_emb_hidden_test["product2vector"],
                      'products_train_vector_dict': product_emb_hidden_train["product2vector"],
                      
                     'unknown_products': []}



joblib.dump(product_similarity_emb_hidden, os.path.join(model_dump_path, "product_similarity_emb_hidden.joblib"))
# Out:
# ['./model\\product_similarity_emb_hidden']

# %% [markdown]
# ## Product Embeddings

# %%
model.text_embeddings
# Out:
# ModuleList(
#   (0): TextRecurrentLayer(
#     (embedding): Embedding(104570, 50, padding_idx=0)
#     (rnn): GRU(50, 100, num_layers=2, batch_first=True, bidirectional=True)
#     (last_time_step): LastTimeStep()
#   )
#   (1): TextRecurrentLayer(
#     (embedding): Embedding(184473, 50, padding_idx=0)
#     (rnn): GRU(50, 100, num_layers=2, batch_first=True, bidirectional=True)
#     (last_time_step): LastTimeStep()
#   )
# )

# %%
# embeddings can have only one product consisting of the same words. Therefore we can prepare our data by removing duplicates on product name level

validation_products_unique = validation.drop_duplicates(subset = "name", keep = "last").reset_index(drop=True)
print(f"validation size: {len(validation_products_unique)}")
train_products_unique = train.drop_duplicates(subset = "name", keep = "last").reset_index(drop=True)
print(f"train size: {len(train_products_unique)}")
# Out:
# validation size: 254660
# train size: 928071

# %%
product_emb_emb_test = utils.get_product_embeddings_from_embedding_layer(model, validation_products_unique["name"],  dd_train, item_column="name")

# %%
# unknown embeddings
product_emb_emb_test["unknown"]
# Out:
# ['lizzz',
#  'j❤️j',
#  'bambiblu',
#  'mbiki',
#  'quibbler',
#  'waxvac',
#  'complications',
#  'jachelle',
#  '❗️vsx tank❗️xs',
#  'tennispuma',
#  "yvonne's",
#  'baketball',
#  'urbandecayallnighterwaterprooffoundation',
#  'uggzzz',
#  'cv012817',
#  'itscosmeticscccreamsamplea',
#  'xirma',
#  'choker‼️',
#  'jeffreystarcosmeticsskinfrost-icecold',
#  'mediastinum',
#  'limecrimechinadoll/sugarpillheartbreake',
#  'tomahawk',
#  'ғᴏʀ ᴋᴇɴᴛᴜᴄᴋʏ85',
#  '♡♡nars bundle♡♡',
#  '⭐️barcelona jersey⭐️',
#  'lesliexcloset',
#  "bow's",
#  'biankas',
#  'ardi',
#  'vercace perfumev',
#  'fcm',
#  'redick',
#  '☆vampress☆',
#  '✨eyeshadow✨',
#  'happy775',
#  'bellossum',
#  '4theluvoflouis',
#  '**cherishbundle**',
#  '⚡elizabeth ameral⚡',
#  "dj'set",
#  'chelsea1',
#  'haleyedmunds (:',
#  'cupcakes91',
#  'ams1991',
#  'ruben',
#  'helloween',
#  'fruiiityslime',
#  'bjtownsend',
#  'vibrams!',
#  'girlactorsneakerhead',
#  'heebwife',
#  'danellco',
#  'ᐯᗩᑎᔕ ᗩᑎᑕᕼoᖇ ᗷᑌᖇgᑌᑎᗪy tᗩᑎk',
#  'eyeluminator',
#  'sunsilk',
#  'maryr40',
#  'wheedle',
#  'caylyn tamayo',
#  'xim4',
#  'reselling',
#  'bridgetollbeading',
#  "concealer's",
#  'franbundle',
#  "andreamarriott'sairmax",
#  'moriama',
#  'mimic',
#  'lillin',
#  'noelgrace97',
#  'kdfabfinds',
#  "val's",
#  'jennifervanz',
#  'minions♥',
#  'luio vattan',
#  'lyfe',
#  'slimekiingg',
#  'nikkic21',
#  'norcodrene',
#  'btrilla',
#  'jsh127',
#  'wintër hëadband',
#  'einhander',
#  'nicholetucker94',
#  'jessicabutterflyirma',
#  'stickers13',
#  'magcargo',
#  'formycloset',
#  'stermay',
#  'lulyboo',
#  'love♥pink♥lanyards',
#  'kᑎo᙭ ᖇoᔕe ᒪᗩᑕe ᔕᕼiᖇt',
#  'lizkunz811',
#  'dixit',
#  'crh',
#  'alycat',
#  'ᏼꭼꭲꮪꭼy jꮎꮋnꮪꮎn ꮮꮎꮤ ꮯꮜꭲ ꮪꮎꮯkꮪ',
#  'cheeze',
#  'lovesoccer7',
#  'tdanniellen',
#  'simplify',
#  'lucifau',
#  'garruk wildspeaker',
#  'dishiki',
#  'nissie',
#  'besom',
#  "arrowhead's",
#  'basucallyallie',
#  'rlfullziphoodedjacket/graypulloverhoodie',
#  'swatchbook',
#  'pendlay dowins',
#  "figuring d'an",
#  'teaaaco',
#  'lemode',
#  'shaelynn',
#  '•lace choker•pink rose•',
#  '♡choker♡',
#  'aluna408',
#  'jomalone',
#  'baitcaste trion',
#  'balman',
#  '***juya***',
#  'flightposite',
#  '@reservedbundle@',
#  'martcastel',
#  'akikunikai2',
#  'hollllddd!',
#  'mimisf',
#  'alelizbeth12',
#  'gracieannsmith5',
#  'xoxsadaf',
#  'broghan',
#  'covencraft&secretsofthemagical grimoires',
#  'tealish gemstoneflowerrusticcuffbracelet',
#  'plushebtq',
#  'cyanidekat',
#  'w2k15',
#  'wonderbronze',
#  'logistics mous',
#  '⚠toddler vans⚠',
#  'kitttae',
#  'makeupfanatic',
#  'shoulias',
#  'iasotea',
#  'tk2007',
#  'doonefees',
#  'abzù',
#  'mandynfloyd23',
#  'merendam',
#  'rufflebutts',
#  "supra's",
#  'emily630',
#  'kyliener',
#  'kieara',
#  'heathermarie711',
#  'pspvita!!',
#  '☆bundel☆',
#  '☆jagermeister speaker☆',
#  '{•ambaisuhmazing•}',
#  'cnco',
#  '☆☆for lucebox☆☆',
#  '✨casey marie✨',
#  '✨✨vizio tv✨✨',
#  'freeship‼️ eyelashes‼️',
#  'kelis',
#  'mabkhara',
#  'emmyisaacs',
#  'buy2get2free✨kylie lip❤️',
#  'maka9',
#  'nyx•lip lingerie•new',
#  'zombiecide',
#  'bbshorts s010',
#  'shoppingaddict125',
#  'phomeposits',
#  'nyckelly',
#  'mirna',
#  'flaskzilla',
#  'sydney4208',
#  'ekyrie17',
#  'sky3ds',
#  'zootalkers',
#  'superglue',
#  'ꮯꭱꭺꮯkꮮꭼꭰ ꮹꮮꭺꮪꮪ fꮮꮎꭱꭺꮮ jꭼꮤꭼꮮꭱy ꭰiꮪꮋ',
#  'solemates',
#  'dermatalogica',
#  "pokemon's",
#  'bru8903',
#  'jensmith451',
#  'holdddddrenee',
#  'samples✨✨✨',
#  'kaii',
#  'asreyes8022',
#  'vink',
#  'volumetric spirometer',
#  'avalance',
#  'mkpurse',
#  'siliblender',
#  'fluffybubbles',
#  'mrsjtross',
#  'ctc10000010151019',
#  '✨arrow earring✨',
#  '✨✨diamond choker✨✨',
#  'floofslimes',
#  'grammadoo',
#  'kaiclothingbtq',
#  'bundlecba',
#  'vbralingerieblackkhaki40dholdforbklynma1',
#  'dcgirl',
#  'mcmxc15co',
#  '♨coffee press♨',
#  'vibundle',
#  'ᴍᴀʀʏ ᴊᴀɴᴇ ғʟᴀᴛs',
#  'colombians',
#  '☆freeship☆rosary',
#  '⚡️waist trainer⚡️',
#  'infinityirene',
#  '**mlimurphybundle**',
#  'makaela dolen',
#  'loubs',
#  '@missestrada',
#  'emilia0817',
#  'elephant♥',
#  'daphneblue',
#  'boutiqua',
#  'waterpiik',
#  '♨sound machine♨',
#  'phimiaprcn',
#  'jack3d',
#  'theonelinda',
#  'tums freshers antacid',
#  '@holamairim',
#  'ljmitch',
#  '28njacks',
#  'sophiarondinelli',
#  '⚡danskin windbreaker⚡',
#  'mccormick85',
#  '**yogabeauty1bundle**',
#  'speacker',
#  'morpheme',
#  'truffettes',
#  '@anthony3625',
#  'squishiebakery',
#  'hammershot',
#  'adannalh',
#  '♡♡jen succulents♡♡♡',
#  'confidenceinacream',
#  'terrgarden',
#  'jordanssneaker',
#  'mesofx',
#  'alik',
#  'ashley198712',
#  '⛥summer crush⛥bikini',
#  'danielle148',
#  'kyai1.',
#  'lovemychi',
#  'aquazzura',
#  'airbuds',
#  'annalis',
#  "victoria'ssecretbralette",
#  'rd06221',
#  'galbraith99',
#  "'starry eyed'.",
#  '⚡️lularoe⚡️xl',
#  'mocu',
#  'ap64d',
#  'sentinnel',
#  'princessxo',
#  'lhack21',
#  'abigail87',
#  'nelsonamber21',
#  'joanabird',
#  'ziggy04',
#  'mariocart',
#  '**maryloubundle**',
#  'sickynikkie',
#  'franklyfrankie',
#  'yleos',
#  'magistas',
#  'abandon',
#  'ipath',
#  'camillezatss69',
#  'fiendishkid',
#  'stephanieh',
#  'inarock',
#  'shinebright',
#  'boutonnieres',
#  'alliecat365',
#  'alextan',
#  'kasaundj7',
#  'lipbalmlover',
#  '**farmgirl**',
#  'curatedciolshop']

# %%
product_emb_emb_train = utils.get_product_embeddings_from_embedding_layer(model, train_products_unique["name"], dd_train, item_column="name")

# %%
product_emb_emb_test["product2vector"].keys()

# %%
search_product = "express portofino blouse size m"
product_name = search_product
cos = cosine_similarity(product_emb_emb_train["matrix"], product_emb_emb_test["product2vector"][product_name].reshape(1, -1))
print(cos.shape)
top_n = np.argsort(cos, axis=0, )[-10:][::-1].reshape(-1)
top_similarity = cos[top_n].reshape(-1)
print(top_n, top_similarity)
# Out:
# (928071, 1)
# [431918 244818 342449 347572 349672 361556 588136 923594 555160 381739] [0.76878326 0.69302587 0.6872537  0.67367575 0.67263427 0.65950813
#  0.65465092 0.65143845 0.65067749 0.64973632]

# %%
tmp = validation_products_unique[validation_products_unique["name"] == search_product]

html = tmp[["name", "item_condition_id", "category_name", "brand_name", "shipping", "item_description", "is_brand_missing", "price"]].to_html()#(classes='table table-stripped')
text_file = open(f"{search_product}_search_word_embedding.html", "w")
text_file.write(html)
text_file.close()

tmp
# Out:
#             id                             name item_condition_id                category_name brand_name  shipping                                                                                               item_description  desc_len  name_len subcategory_1   subcategory_2 subcategory_3  is_brand_missing  is_item_description_missing  price  price_log
# 78925  1210035  express portofino blouse size m                 2  Women/Tops & Blouses/Blouse    express       1.0  portofino blouse from express. only worn a couple time and in like new condition. size medium. free shipping!      18.0       5.0         women  tops & blouses        blouse               0.0                          0.0    9.0   2.302585

# %%
tmp = train_products_unique.iloc[top_n].copy().assign(similarity = top_similarity).head()
html = tmp[["name", "item_condition_id", "category_name", "brand_name", "shipping", "item_description", "is_brand_missing", "price", "similarity"]].to_html()#(classes='table table-stripped')
text_file = open(f"{search_product}_word_embedding.html", "w")
text_file.write(html)
text_file.close()

tmp
# Out:
#              id                                    name item_condition_id                           category_name    brand_name  shipping                                                                                                                                                                                                                                item_description  desc_len  name_len subcategory_1   subcategory_2      subcategory_3  is_brand_missing  is_item_description_missing  price  price_log  similarity
# 431918   930847                express portofino blouse                 3  Women/Tops & Blouses/Button Down Shirt       express       0.0                                                                        this shirt was hardly worn in great condition . it's a coral pink but the picture doesn't do it justice ! very soft and silky these shirts usually retail for 49.90 & up      33.0       3.0         women  tops & blouses  button down shirt               0.0                          0.0   18.0   2.944439    0.768783
# 244818   750417   new women's plus size blouse, size 18                 2             Women/Tops & Blouses/Blouse  susan graver       0.0                                                                                                                                                      new, no tags. women's blouse, black with blue flowers. it's a 2 piece, see last 2 pictures      17.0       7.0         women  tops & blouses             blouse               0.0                          0.0   15.0   2.772589    0.693026
# 342449  1313888           women's plus size lace blouse                 1             Women/Tops & Blouses/Blouse       missing       1.0  blouse has accent studs across the front, with lace throughout the top. the blouse has a lining underneath the lace everywhere except the sleeves. great with skirts or pants available in sizes 0x, 1x,3x ask for your size, bundle and save.      41.0       5.0         women  tops & blouses             blouse               1.0                          0.0   13.0   2.639057    0.687254
# 347572  1394180                   plus size lace blouse                 2             Women/Tops & Blouses/Blouse       missing       1.0                                                                                                                                                                                                  mocha color lace over same color attached cami       8.0       4.0         women  tops & blouses             blouse               1.0                          0.0   18.0   2.944439    0.673676
# 349672   423085  (m) white express sleeveless portofino                 2             Women/Tops & Blouses/Blouse       express       0.0                                                                        express portofino - sleeveless tank size medium - would fit size small in flowy style. nwot - perfect condition never worn. tank top button down dress shirt work blouse      29.0       5.0         women  tops & blouses             blouse               0.0                          0.0   17.0   2.890372    0.672634

# %%
import joblib
product_similarity_emb_emb = {
                      'train': train, 'test': validation,
                      'product_train_embedding_matrix': product_emb_emb_train["matrix"], 
                      'products_test_vector_dict': product_emb_emb_test["product2vector"], 
                      'products_train_vector_dict': product_emb_emb_train["product2vector"],
                      'unknown_products': product_emb_emb_test["unknown"]}


joblib.dump(product_similarity_emb_emb, os.path.join(model_dump_path, "product_similarity_emb_emb.joblib"))
# Out:
# ['./model\\product_similarity_emb_emb.joblib']
